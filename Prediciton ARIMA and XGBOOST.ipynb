# %%
import numpy as np
import pandas as pd
import dask.dataframe as dd
import yfinance as yf
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.dates as mdates

# Data Preparation
stocks = ['TCS.NS', 'RELIANCE.NS', 'HDFCBANK.NS', 'INFY.NS', 'ITC.NS']
data = {}

for stock in stocks:
    try:
        df = yf.download(stock, start='2010-01-01', end='2024-01-01')
        data[stock] = df
    except Exception as e:
        print(f"Error downloading data for {stock}: {e}")
        continue

# Using Dask for handling large datasets
data = {stock: dd.from_pandas(df, npartitions=4) for stock, df in data.items()}

# Data Cleaning
for stock, ddf in data.items():
    ddf = ddf.dropna()  # Drop rows with missing values
    z_scores = ddf.map_partitions(lambda df: np.abs(stats.zscore(df.select_dtypes(include=[np.number]))))
    ddf = ddf[(z_scores < 3).all(axis=1)]
    data[stock] = ddf

# Output
results = []

# Exploratory Data Analysis (EDA) and Feature Engineering
for stock, ddf in data.items():
    df = ddf.compute()
    
    # Perform feature engineering
    # Print summary statistics
    print(f"Summary statistics for {stock}:")
    print(df.describe())
    
    # Plot stock price over time
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df['Close'])
    plt.title(f'{stock} Stock Price Over Time')
    plt.show()
    
    # Plot ACF and PACF
    plot_acf(df['Close'])
    plt.title(f'Autocorrelation Function for {stock}')
    plt.show()
    
    plot_pacf(df['Close'])
    plt.title(f'Partial Autocorrelation Function for {stock}')
    plt.show()
    
    # Perform feature engineering
    df.loc[:, f'{stock}_lag1'] = df['Close'].shift(1)
    df.loc[:, f'{stock}_lag5'] = df['Close'].shift(5)
    df.loc[:, f'{stock}_lag10'] = df['Close'].shift(10)
    df.loc[:, f'{stock}_roll_mean'] = df['Close'].rolling(window=20).mean()
    df.loc[:, f'{stock}_roll_std'] = df['Close'].rolling(window=20).std()
    df.loc[:, f'{stock}_pct_change'] = (df['Close'] - df['Close'].shift(1)) / df['Close'].shift(1)
    
    print(f"Feature-engineered data for {stock}:")
    print(df.head())
    
    # Replace cleaned data back into Dask DataFrame
    data[stock] = dd.from_pandas(df, npartitions=4)
    
    # ARIMA Model
    arima_model = ARIMA(df['Close'], order=(5, 1, 0))
    arima_fit = arima_model.fit()
    arima_forecast = arima_fit.forecast(steps=len(df))
    
    # Plot ARIMA forecast
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Actual Prices')
    plt.plot(df.index, arima_forecast, label='ARIMA Forecasted Prices')
    plt.title(f'ARIMA Model for {stock}')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.gcf().autofmt_xdate()
    plt.legend()
    plt.show()

    # Gradient Boosting Model (XGBoost)
    X = df.drop(['Close'], axis=1)
    y = df['Close']

    model = XGBRegressor(missing=np.nan)
    model.fit(X, y)

    # Hyperparameter tuning with GridSearchCV
    params = {'max_depth': [3, 5, 7], 'learning_rate': [0.1, 0.5, 1]}
    grid_search = GridSearchCV(model, params, cv=5, scoring='neg_mean_squared_error')
    grid_search.fit(X, y)

    print(f'Best Parameters for XGBoost model on {stock}:', grid_search.best_params_)
    print(f'Best Score for XGBoost model on {stock}:', grid_search.best_score_)

    # Train XGBoost model with best parameters
    model = XGBRegressor(**grid_search.best_params_, missing=np.nan)
    model.fit(X, y)

    xgboost_forecast = model.predict(X[-30:])
    
    # Calculate metrics for ARIMA and XGBoost models
    arima_rmse = np.sqrt(mean_squared_error(y_true=df['Close'][-30:], y_pred=arima_forecast[-30:]))
    arima_mae = mean_absolute_error(y_true=df['Close'][-30:], y_pred=arima_forecast[-30:])
    arima_mape = mean_absolute_percentage_error(y_true=df['Close'][-30:], y_pred=arima_forecast[-30:])
    
    xgboost_rmse = np.sqrt(mean_squared_error(y_true=y[-30:], y_pred=xgboost_forecast))
    xgboost_mae = mean_absolute_error(y_true=y[-30:], y_pred=xgboost_forecast)
    xgboost_mape = mean_absolute_percentage_error(y_true=y[-30:], y_pred=xgboost_forecast)

    # Print metrics
    print(f'ARIMA Model Metrics for {stock}:')
    print('RMSE:', arima_rmse)
    print('MAE:', arima_mae)
    print('MAPE:', arima_mape)
    
    print(f'XGBoost Model Metrics for {stock}:')
    print('RMSE:', xgboost_rmse)
    print('MAE:', xgboost_mae)
    print('MAPE:', xgboost_mape)
    
    # Append results to the list
    results.append({
        'Stock': stock,
        'Date': df.index[-30:].tolist(),
        'Actual': df['Close'][-30:].tolist(),
        'ARIMA_Predicted': arima_forecast[-30:].tolist(),
        'XGBoost_Predicted': xgboost_forecast.tolist(),
        'ARIMA_RMSE': arima_rmse,
        'ARIMA_MAE': arima_mae,
        'ARIMA_MAPE': arima_mape,
        'XGBoost_RMSE': xgboost_rmse,
        'XGBoost_MAE': xgboost_mae,
        'XGBoost_MAPE': xgboost_mape
    })

# Save results to CSV
output_df = pd.DataFrame(results)
output_df.to_csv('C:/Users/sajid/Invsto/model_predictions_and_metrics.csv', index=False)

print("Results saved to model_predictions_and_metrics.csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Summary statistics for TCS.NS:
#               Open         High          Low        Close    Adj Close  \
# count  3392.000000  3392.000000  3392.000000  3392.000000  3392.000000
# mean   1696.545046  1713.218135  1678.783959  1695.965787  1529.654411
# std    1039.791478  1047.979328  1030.549341  1039.250638  1036.652208
# min     352.000000   357.000000   342.625000   349.774994   264.444092
# 25%     787.125000   797.062515   780.143738   790.650009   628.105835
# 50%    1283.000000  1297.312500  1272.750000  1285.125000  1083.667419
# 75%    2255.250000  2270.250000  2232.037476  2252.812561  2053.186096
# max    4033.949951  4043.000000  3980.000000  4019.149902  3813.681641
#
#              Volume
# count  3.392000e+03
# mean   2.639663e+06
# std    1.381082e+06
# min    0.000000e+00
# 25%    1.684444e+06
# 50%    2.297280e+06
# 75%    3.199280e+06
# max    1.259307e+07
# Feature-engineered data for TCS.NS:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04  377.399994  379.450012  374.524994  375.825012  284.037415
# 2010-01-05  377.500000  379.774994  373.274994  375.924988  284.112976
# 2010-01-06  375.924988  376.100006  366.500000  367.424988  277.688934
# 2010-01-07  367.750000  369.700012  355.500000  357.200012  269.961182
# 2010-01-08  358.000000  359.250000  348.250000  349.899994  264.444092
#
#              Volume  TCS.NS_lag1  TCS.NS_lag5  TCS.NS_lag10  TCS.NS_roll_mean  \
# Date
# 2010-01-04  1963682          NaN          NaN           NaN               NaN
# 2010-01-05  2014488   375.825012          NaN           NaN               NaN
# 2010-01-06  3349176   375.924988          NaN           NaN               NaN
# 2010-01-07  6474892   367.424988          NaN           NaN               NaN
# 2010-01-08  6048178   357.200012          NaN           NaN               NaN
#
#             TCS.NS_roll_std  TCS.NS_pct_change
# Date
# 2010-01-04              NaN                NaN
# 2010-01-05              NaN           0.000266
# 2010-01-06              NaN          -0.022611
# 2010-01-07              NaN          -0.027829
# 2010-01-08              NaN          -0.020437
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Best Parameters for XGBoost model on TCS.NS: {'learning_rate': 0.1, 'max_depth': 3}
# Best Score for XGBoost model on TCS.NS: -48101.53287299522
# ARIMA Model Metrics for TCS.NS:
# RMSE: 219.38280205771605
# MAE: 181.79092481589814
# MAPE: 0.051508335925479314
# XGBoost Model Metrics for TCS.NS:
# RMSE: 12.146448188217082
# MAE: 9.1942138671875
# MAPE: 0.0025188348185376463
# Summary statistics for RELIANCE.NS:
#               Open         High          Low        Close    Adj Close  \
# count  3400.000000  3400.000000  3400.000000  3400.000000  3400.000000
# mean   1005.603438  1015.943055   994.453587  1004.705781   981.693102
# std     745.003249   751.866255   737.606488   744.552629   751.382344
# min     308.587280   312.153198   307.695831   309.090179   281.488586
# 25%     419.970146   425.404732   414.781334   418.884377   391.114769
# 50%     500.688599   506.608887   495.396896   499.111374   473.432739
# 75%    1638.324432  1657.522858  1609.053772  1631.159637  1614.503265
# max    2636.225586  2636.225586  2586.850098  2623.026611  2613.793457
#
#              Volume
# count  3.400000e+03
# mean   8.634792e+06
# std    4.598682e+06
# min    0.000000e+00
# 25%    5.557442e+06
# 50%    7.448494e+06
# 75%    1.030340e+07
# max    3.354253e+07
# Feature-engineered data for RELIANCE.NS:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-05  525.695618  525.695618  487.065033  489.488007  438.456360
# 2010-01-06  493.693939  500.368591  489.465149  497.397003  445.540802
# 2010-01-07  497.397003  509.740479  492.825348  505.648834  452.932343
# 2010-01-08  506.540314  509.191895  501.054321  504.323059  451.744781
# 2010-01-12  500.597168  519.935303  492.368164  495.728333  444.046051
#
#               Volume  RELIANCE.NS_lag1  RELIANCE.NS_lag5  RELIANCE.NS_lag10  \
# Date
# 2010-01-05  10696412               NaN               NaN                NaN
# 2010-01-06  11845880        489.488007               NaN                NaN
# 2010-01-07  13098960        497.397003               NaN                NaN
# 2010-01-08   7555074        505.648834               NaN                NaN
# 2010-01-12  16395254        504.323059               NaN                NaN
#
#             RELIANCE.NS_roll_mean  RELIANCE.NS_roll_std  \
# Date
# 2010-01-05                    NaN                   NaN
# 2010-01-06                    NaN                   NaN
# 2010-01-07                    NaN                   NaN
# 2010-01-08                    NaN                   NaN
# 2010-01-12                    NaN                   NaN
#
#             RELIANCE.NS_pct_change
# Date
# 2010-01-05                     NaN
# 2010-01-06                0.016158
# 2010-01-07                0.016590
# 2010-01-08               -0.002622
# 2010-01-12               -0.017042
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Best Parameters for XGBoost model on RELIANCE.NS: {'learning_rate': 1, 'max_depth': 7}
# Best Score for XGBoost model on RELIANCE.NS: -29748.305119045668
# ARIMA Model Metrics for RELIANCE.NS:
# RMSE: 146.87179749012898
# MAE: 125.99540958415528
# MAPE: 0.052239273650656705
# XGBoost Model Metrics for RELIANCE.NS:
# RMSE: 0.08085203767126278
# MAE: 0.05901692708333333
# MAPE: 2.422233301802751e-05
# Summary statistics for HDFCBANK.NS:
#               Open         High          Low        Close    Adj Close  \
# count  3402.000000  3402.000000  3402.000000  3402.000000  3402.000000
# mean    805.483996   812.712029   797.644955   805.362577   767.703703
# std     492.481865   496.470546   488.204919   492.308152   484.730454
# min     156.679993   157.789993   154.899994   156.740005   139.597702
# 25%     331.012497   334.525002   327.406250   331.112495   302.743805
# 50%     646.162506   650.000000   641.674988   645.250000   606.306000
# 75%    1239.987488  1248.300018  1227.487549  1239.450012  1189.663574
# max    1723.449951  1757.500000  1713.800049  1728.199951  1704.918579
#
#              Volume
# count  3.402000e+03
# mean   6.709506e+06
# std    5.046769e+06
# min    0.000000e+00
# 25%    3.278064e+06
# 50%    5.347248e+06
# 75%    8.319539e+06
# max    3.361002e+07
# Feature-engineered data for HDFCBANK.NS:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04  170.000000  172.850006  169.255005  170.570007  151.915100
# 2010-01-05  171.000000  172.500000  170.500000  170.720001  152.048721
# 2010-01-06  171.399994  172.000000  168.809998  170.835007  152.151138
# 2010-01-07  176.839996  176.839996  170.160004  171.279999  152.547440
# 2010-01-08  171.199997  172.339996  170.100006  171.505005  152.747849
#
#              Volume  HDFCBANK.NS_lag1  HDFCBANK.NS_lag5  HDFCBANK.NS_lag10  \
# Date
# 2010-01-04  3050490               NaN               NaN                NaN
# 2010-01-05  8386600        170.570007               NaN                NaN
# 2010-01-06  6639840        170.720001               NaN                NaN
# 2010-01-07  6123980        170.835007               NaN                NaN
# 2010-01-08  7085900        171.279999               NaN                NaN
#
#             HDFCBANK.NS_roll_mean  HDFCBANK.NS_roll_std  \
# Date
# 2010-01-04                    NaN                   NaN
# 2010-01-05                    NaN                   NaN
# 2010-01-06                    NaN                   NaN
# 2010-01-07                    NaN                   NaN
# 2010-01-08                    NaN                   NaN
#
#             HDFCBANK.NS_pct_change
# Date
# 2010-01-04                     NaN
# 2010-01-05                0.000879
# 2010-01-06                0.000674
# 2010-01-07                0.002605
# 2010-01-08                0.001314
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Best Parameters for XGBoost model on HDFCBANK.NS: {'learning_rate': 0.1, 'max_depth': 3}
# Best Score for XGBoost model on HDFCBANK.NS: -3627.0366999502935
# ARIMA Model Metrics for HDFCBANK.NS:
# RMSE: 128.96765920565696
# MAE: 106.88204142202743
# MAPE: 0.06888891090415293
# XGBoost Model Metrics for HDFCBANK.NS:
# RMSE: 4.434196093025861
# MAE: 3.611376953125
# MAPE: 0.00228777051703242
# Summary statistics for INFY.NS:
#               Open         High          Low        Close    Adj Close  \
# count  3411.000000  3411.000000  3411.000000  3411.000000  3411.000000
# mean    729.198771   736.442198   721.816898   729.148027   645.939527
# std     450.365261   454.201952   446.095119   450.146970   457.929988
# min     270.000000   270.500000   257.568756   265.475006   200.857971
# 25%     385.390625   390.462494   381.278122   386.568756   291.862961
# 50%     543.200012   549.000000   535.275024   542.450012   439.305359
# 75%     831.774994   837.725006   825.325012   830.549988   736.646057
# max    1938.550049  1953.900024  1930.500000  1939.500000  1838.948853
#
#              Volume
# count  3.411000e+03
# mean   8.000455e+06
# std    4.229501e+06
# min    0.000000e+00
# 25%    5.261786e+06
# 50%    6.927885e+06
# 75%    9.444675e+06
# max    3.534468e+07
# Feature-engineered data for INFY.NS:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04  326.250000  328.750000  324.412506  326.575012  239.087799
# 2010-01-05  327.500000  328.837494  325.012512  327.668762  239.888504
# 2010-01-06  335.375000  335.375000  321.887512  322.887512  236.388138
# 2010-01-07  323.325012  323.325012  314.774994  315.631256  231.075821
# 2010-01-08  314.875000  315.412506  307.250000  308.024994  225.507263
#
#               Volume  INFY.NS_lag1  INFY.NS_lag5  INFY.NS_lag10  \
# Date
# 2010-01-04   4069264           NaN           NaN            NaN
# 2010-01-05   6895528    326.575012           NaN            NaN
# 2010-01-06   6817288    327.668762           NaN            NaN
# 2010-01-07  10892600    322.887512           NaN            NaN
# 2010-01-08  12649312    315.631256           NaN            NaN
#
#             INFY.NS_roll_mean  INFY.NS_roll_std  INFY.NS_pct_change
# Date
# 2010-01-04                NaN               NaN                 NaN
# 2010-01-05                NaN               NaN            0.003349
# 2010-01-06                NaN               NaN           -0.014592
# 2010-01-07                NaN               NaN           -0.022473
# 2010-01-08                NaN               NaN           -0.024099
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Best Parameters for XGBoost model on INFY.NS: {'learning_rate': 0.5, 'max_depth': 7}
# Best Score for XGBoost model on INFY.NS: -17964.366198051666
# ARIMA Model Metrics for INFY.NS:
# RMSE: 71.48971872017913
# MAE: 61.35347291748706
# MAPE: 0.041940724259458516
# XGBoost Model Metrics for INFY.NS:
# RMSE: 0.31315071544775624
# MAE: 0.24463704427083333
# MAPE: 0.00016466286442262253
# Summary statistics for ITC.NS:
#               Open         High          Low        Close    Adj Close  \
# count  3380.000000  3380.000000  3380.000000  3380.000000  3380.000000
# mean    231.868452   234.097475   229.343905   231.712327   189.996075
# std      79.279479    79.792536    78.659777    79.207885    82.263848
# min      78.366669    81.400002    78.333336    80.650002    56.333855
# 25%     194.366661   196.424999   192.037502   194.124996   148.793236
# 50%     227.283333   229.333328   224.000000   226.699997   180.783966
# 75%     268.750000   271.149994   266.399994   268.637489   216.565384
# max     493.450012   499.700012   487.000000   492.149994   476.573608
#
#              Volume
# count  3.380000e+03
# mean   1.295598e+07
# std    8.677570e+06
# min    0.000000e+00
# 25%    7.647444e+06
# 50%    1.032448e+07
# 75%    1.541389e+07
# max    6.760782e+07
# Feature-engineered data for ITC.NS:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2010-01-04  84.333336  85.000000  83.449997  84.550003  59.057999   5161635
# 2010-01-05  84.933334  85.583336  84.233330  85.383331  59.640083  10767225
# 2010-01-06  86.233330  86.233330  84.533333  85.583336  59.779789   7529979
# 2010-01-07  85.666664  86.166664  84.566666  85.316666  59.593506   4987434
# 2010-01-08  85.116669  86.166664  85.116669  85.500000  59.721565   4881351
#
#             ITC.NS_lag1  ITC.NS_lag5  ITC.NS_lag10  ITC.NS_roll_mean  \
# Date
# 2010-01-04          NaN          NaN           NaN               NaN
# 2010-01-05    84.550003          NaN           NaN               NaN
# 2010-01-06    85.383331          NaN           NaN               NaN
# 2010-01-07    85.583336          NaN           NaN               NaN
# 2010-01-08    85.316666          NaN           NaN               NaN
#
#             ITC.NS_roll_std  ITC.NS_pct_change
# Date
# 2010-01-04              NaN                NaN
# 2010-01-05              NaN           0.009856
# 2010-01-06              NaN           0.002342
# 2010-01-07              NaN          -0.003116
# 2010-01-08              NaN           0.002149
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sajid\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Best Parameters for XGBoost model on ITC.NS: {'learning_rate': 1, 'max_depth': 3}
# Best Score for XGBoost model on ITC.NS: -1109.8673226920032
# ARIMA Model Metrics for ITC.NS:
# RMSE: 15.204167153781798
# MAE: 12.417068964279027
# MAPE: 0.02802857212798884
# XGBoost Model Metrics for ITC.NS:
# RMSE: 0.8341450441721932
# MAE: 0.6479461669921875
# MAPE: 0.0014488409113820803
# Results saved to model_predictions_and_metrics.csv
